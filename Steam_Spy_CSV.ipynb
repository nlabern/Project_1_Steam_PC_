# %%
#Read Steam_Spy CSV File intead of contacting the API every time
import requests
import json
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import os
from pathlib import Path

# %%
#Read the file
steam_spy_csv = Path("Output_Data/steamspy.csv")

# %%
steam_spy_df = pd.read_csv(steam_spy_csv)
steam_spy_df.head()
# Out:
#    Unnamed: 0               578080     1623730             252490  \
# 0       appid               578080     1623730             252490
# 1        name  PUBG: BATTLEGROUNDS    Palworld               Rust
# 2   developer        KRAFTON, Inc.  Pocketpair  Facepunch Studios
# 3   publisher        KRAFTON, Inc.  Pocketpair  Facepunch Studios
# 4  score_rank                  NaN         NaN                NaN
#
#                   304930                      553850              291550  \
# 0                 304930                      553850              291550
# 1               Unturned                HELLDIVERS 2          Brawlhalla
# 2  Smartly Dressed Games      Arrowhead Game Studios  Blue Mammoth Games
# 3  Smartly Dressed Games  PlayStation Publishing LLC             Ubisoft
# 4                    NaN                         NaN                 NaN
#
#            1086940                 431960  \
# 0          1086940                 431960
# ...
