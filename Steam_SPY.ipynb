# %%
import requests
import json
from matplotlib import pyplot as plt
import pandas as pd

# %%
#Data from the "Steam Spy API"
steam_spy_url = "https://www.steamspy.com/api.php?request=all&page=1"
print(requests.get(steam_spy_url))
response = requests.get(steam_spy_url).json()
print(json.dumps(response, indent=4, sort_keys=5))
# Out:
# <Response [200]>
# {
#     "1007040": {
#         "appid": 1007040,
#         "average_2weeks": 0,
#         "average_forever": 0,
#         "ccu": 731,
#         "developer": "SANDLOT",
#         "discount": "0",
#         "initialprice": "5999",
#         "median_2weeks": 0,
#         "median_forever": 0,
#         "name": "EARTH DEFENSE FORCE 5",
#         "negative": 524,
#         "owners": "500,000 .. 1,000,000",
#         "positive": 9351,
#         "price": "5999",
#         "publisher": "D3PUBLISHER",
#         "score_rank": "",
#         "userscore": 0
#     },
#     "1009850": {
#         "appid": 1009850,
#         "average_2weeks": 0,
#         "average_forever": 0,
#         "ccu": 4695,
#         "developer": "OVRAS Team",
#         "discount": "0",
#         "initialprice": "799",
#         "median_2weeks": 0,
#         "median_forever": 0,
#         "name": "OVR Advanced Settings",
#         "negative": 193,
#         "owners": "500,000 .. 1,000,000",
# ...

# %%
steam_spy_pd = pd.DataFrame(response)
steam_spy_pd.head()
# Out:
#                                          654880            252150  \
# appid                                    654880            252150
# name        Dream Daddy: A Dad Dating Simulator             Grimm
# developer                           Game Grumps  Spicyhorse Games
# publisher                           Game Grumps  Spicyhorse Games
# score_rank
#
#                                      1259970           613010      368370  \
# appid                                1259970           613010      368370
# name        eFootball PES 2021 SEASON UPDATE  Secret in Story   Her Story
# developer       Konami Digital Entertainment       Naivus Luo  Sam Barlow
# publisher       Konami Digital Entertainment       Naivus Luo  Sam Barlow
# score_rank
#
#                          668630                 558100           490220  \
# appid                    668630                 558100           490220
# name        Tricolour Lovestory  Art of War: Red Tides         Prismata
# ...
